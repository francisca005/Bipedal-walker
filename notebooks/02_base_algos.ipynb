# %%
import gymnasium as gym
from stable_baselines3 import PPO, SAC, A2C, TD3
from stable_baselines3.common.evaluation import evaluate_policy
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# Pasta para logs
LOG_DIR = "../logs/base_selection"
MODEL_DIR = "../models/base_selection"
os.makedirs(LOG_DIR, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import gymnasium as gym
#       2 from stable_baselines3 import PPO, SAC, A2C, TD3
#       3 from stable_baselines3.common.evaluation import evaluate_policy
#
# ModuleNotFoundError: No module named 'gymnasium'

# %% [markdown]
# # 2. Seleção de Algoritmo e Ajuste de Hiperparâmetros
#
# Nesta etapa, o objetivo é identificar o algoritmo de Reinforcement Learning mais adequado para resolver o ambiente `BipedalWalker-v3` e otimizar o seu desempenho.
#
# Esta fase divide-se em duas partes:
# 1.  **Seleção de Algoritmos:** Um *benchmark* comparativo entre algoritmos On-Policy (PPO, A2C) e Off-Policy (SAC, TD3) usando hiperparâmetros padrão.
# 2.  **Hyperparameter Tuning:** Ajuste fino do algoritmo vencedor para maximizar a estabilidade e a recompensa final.

# %%
# Definimos os algoritmos a testar
algos = {
    "PPO": PPO,
    "SAC": SAC,
    "A2C": A2C,
    "TD3": TD3
}

# Treino rápido (100k a 300k steps) só para ver quem aprende
TIMESTEPS = 150_000 

for name, AlgoClass in algos.items():
    print(f"--- Treinando {name} ---")
    
    env = gym.make("BipedalWalker-v3")
    
    try:
        # Instanciar modelo (MlpPolicy para vetor de estados)
        # verbose=1 mostra a barra de progresso
        model = AlgoClass("MlpPolicy", env, verbose=1, tensorboard_log=LOG_DIR)
        
        # Treinar
        model.learn(total_timesteps=TIMESTEPS, tb_log_name=f"{name}_run")
        
        # Guardar
        model.save(f"{MODEL_DIR}/{name}_base")
        
        # Avaliação rápida final
        mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)
        print(f"Resultado {name}: {mean_reward:.2f} +/- {std_reward:.2f}")
        
    except Exception as e:
        print(f"Erro no {name}: {e}")
    finally:
        env.close()
# Out:
# --- Treinando PPO ---
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ../logs/base_selection\PPO_run_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 580      |
# |    ep_rew_mean     | -105     |
# | time/              |          |
# |    fps             | 1270     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 683         |
# |    ep_rew_mean          | -104        |
# | time/                   |             |
# |    fps                  | 1037        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007628944 |
# |    clip_fraction        | 0.0707      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.68       |
# |    explained_variance   | 0.00434     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 82.9        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00771    |
# |    std                  | 1           |
# |    value_loss           | 79.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 575         |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 961         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010876989 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.62       |
# |    explained_variance   | 0.0725      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.8        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00831    |
# |    std                  | 0.974       |
# |    value_loss           | 33.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 677         |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 905         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.006274956 |
# |    clip_fraction        | 0.0547      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.56       |
# |    explained_variance   | 0.0934      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.8        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00384    |
# |    std                  | 0.97        |
# |    value_loss           | 92          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 831         |
# |    ep_rew_mean          | -107        |
# | time/                   |             |
# |    fps                  | 846         |
# |    iterations           | 5           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007957602 |
# |    clip_fraction        | 0.0947      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.55       |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.214       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00948    |
# |    std                  | 0.966       |
# |    value_loss           | 0.586       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 783         |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 852         |
# |    iterations           | 6           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010526957 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.52       |
# |    explained_variance   | 0.326       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0557      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 0.957       |
# |    value_loss           | 0.398       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 834          |
# |    ep_rew_mean          | -107         |
# | time/                   |              |
# |    fps                  | 841          |
# |    iterations           | 7            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0066417954 |
# |    clip_fraction        | 0.0398       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.5         |
# |    explained_variance   | 0.296        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.1         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00702     |
# |    std                  | 0.958        |
# |    value_loss           | 51.3         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 760        |
# |    ep_rew_mean          | -107       |
# | time/                   |            |
# |    fps                  | 836        |
# |    iterations           | 8          |
# |    time_elapsed         | 19         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.00902971 |
# |    clip_fraction        | 0.0681     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.48      |
# |    explained_variance   | -1.18      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00296   |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.00756   |
# |    std                  | 0.947      |
# |    value_loss           | 0.0874     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 768          |
# |    ep_rew_mean          | -107         |
# | time/                   |              |
# |    fps                  | 817          |
# |    iterations           | 9            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0055015692 |
# |    clip_fraction        | 0.0313       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.46        |
# |    explained_variance   | 0.377        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.5         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00415     |
# |    std                  | 0.946        |
# |    value_loss           | 64.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 728          |
# |    ep_rew_mean          | -108         |
# | time/                   |              |
# |    fps                  | 813          |
# |    iterations           | 10           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0064717783 |
# |    clip_fraction        | 0.0418       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.45        |
# |    explained_variance   | 0.622        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.06         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00582     |
# |    std                  | 0.944        |
# |    value_loss           | 19.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 737         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 814         |
# |    iterations           | 11          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.002304314 |
# |    clip_fraction        | 0.00249     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.45       |
# |    explained_variance   | 0.233       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 108         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00302    |
# |    std                  | 0.945       |
# |    value_loss           | 93.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 703          |
# |    ep_rew_mean          | -108         |
# | time/                   |              |
# |    fps                  | 807          |
# |    iterations           | 12           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0071578594 |
# |    clip_fraction        | 0.0728       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.43        |
# |    explained_variance   | 0.32         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.655        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00683     |
# |    std                  | 0.937        |
# |    value_loss           | 28.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 693          |
# |    ep_rew_mean          | -108         |
# | time/                   |              |
# |    fps                  | 806          |
# |    iterations           | 13           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0037141503 |
# |    clip_fraction        | 0.0141       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.42        |
# |    explained_variance   | 0.515        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.1         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00594     |
# |    std                  | 0.937        |
# |    value_loss           | 61           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 686          |
# |    ep_rew_mean          | -108         |
# | time/                   |              |
# |    fps                  | 804          |
# |    iterations           | 14           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0046373815 |
# |    clip_fraction        | 0.0262       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.41        |
# |    explained_variance   | 0.792        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.6         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00405     |
# |    std                  | 0.936        |
# |    value_loss           | 24.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 730          |
# |    ep_rew_mean          | -107         |
# | time/                   |              |
# |    fps                  | 795          |
# |    iterations           | 15           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0042942893 |
# |    clip_fraction        | 0.0317       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.41        |
# |    explained_variance   | 0.699        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.09         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00605     |
# |    std                  | 0.937        |
# |    value_loss           | 33.9         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 734        |
# |    ep_rew_mean          | -107       |
# | time/                   |            |
# |    fps                  | 787        |
# |    iterations           | 16         |
# |    time_elapsed         | 41         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.00980406 |
# |    clip_fraction        | 0.123      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.39      |
# |    explained_variance   | 0.357      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.049      |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0112    |
# |    std                  | 0.925      |
# |    value_loss           | 0.402      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 753          |
# |    ep_rew_mean          | -106         |
# | time/                   |              |
# |    fps                  | 777          |
# |    iterations           | 17           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0046656756 |
# |    clip_fraction        | 0.0456       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.35        |
# |    explained_variance   | 0.62         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0555       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0028      |
# |    std                  | 0.919        |
# |    value_loss           | 11           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 771         |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 776         |
# |    iterations           | 18          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009063141 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.32       |
# |    explained_variance   | 0.0882      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0034      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 0.912       |
# |    value_loss           | 0.105       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 791         |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 778         |
# |    iterations           | 19          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.010904453 |
# |    clip_fraction        | 0.0902      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.23       |
# |    explained_variance   | -1.73       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0121      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00918    |
# |    std                  | 0.885       |
# |    value_loss           | 0.113       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 793          |
# |    ep_rew_mean          | -105         |
# | time/                   |              |
# |    fps                  | 780          |
# |    iterations           | 20           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0066055586 |
# |    clip_fraction        | 0.0678       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.18        |
# |    explained_variance   | 0.6          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.64         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00731     |
# |    std                  | 0.883        |
# |    value_loss           | 11.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 808         |
# |    ep_rew_mean          | -104        |
# | time/                   |             |
# |    fps                  | 779         |
# |    iterations           | 21          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.007575663 |
# |    clip_fraction        | 0.0741      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.18       |
# |    explained_variance   | 0.726       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.14        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00539    |
# |    std                  | 0.885       |
# |    value_loss           | 6.89        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 809         |
# |    ep_rew_mean          | -104        |
# | time/                   |             |
# |    fps                  | 782         |
# |    iterations           | 22          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.012769557 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.15       |
# |    explained_variance   | 0.243       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0102     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00905    |
# |    std                  | 0.87        |
# |    value_loss           | 0.285       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 824          |
# |    ep_rew_mean          | -103         |
# | time/                   |              |
# |    fps                  | 784          |
# |    iterations           | 23           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0077099204 |
# |    clip_fraction        | 0.0518       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.12        |
# |    explained_variance   | 0.786        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.23         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00726     |
# |    std                  | 0.871        |
# |    value_loss           | 6.26         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 825         |
# |    ep_rew_mean          | -103        |
# | time/                   |             |
# |    fps                  | 786         |
# |    iterations           | 24          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.005420929 |
# |    clip_fraction        | 0.0535      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.11       |
# |    explained_variance   | 0.916       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.31        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00522    |
# |    std                  | 0.867       |
# |    value_loss           | 5.6         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 825         |
# |    ep_rew_mean          | -102        |
# | time/                   |             |
# |    fps                  | 787         |
# |    iterations           | 25          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.006930317 |
# |    clip_fraction        | 0.0823      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.09       |
# |    explained_variance   | -0.247      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.8        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00733    |
# |    std                  | 0.864       |
# |    value_loss           | 38.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 837         |
# |    ep_rew_mean          | -101        |
# | time/                   |             |
# |    fps                  | 787         |
# |    iterations           | 26          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.010288975 |
# |    clip_fraction        | 0.0893      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.08       |
# |    explained_variance   | 0.0293      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.21        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00622    |
# |    std                  | 0.861       |
# |    value_loss           | 23.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 837         |
# |    ep_rew_mean          | -100        |
# | time/                   |             |
# |    fps                  | 788         |
# |    iterations           | 27          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.014396558 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.04       |
# |    explained_variance   | -0.794      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.109       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.011      |
# |    std                  | 0.849       |
# |    value_loss           | 0.339       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 848         |
# |    ep_rew_mean          | -99.9       |
# | time/                   |             |
# |    fps                  | 789         |
# |    iterations           | 28          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.004570754 |
# |    clip_fraction        | 0.0374      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.01       |
# |    explained_variance   | 0.54        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.03        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0053     |
# |    std                  | 0.849       |
# |    value_loss           | 33.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 859        |
# |    ep_rew_mean          | -99.5      |
# | time/                   |            |
# |    fps                  | 788        |
# |    iterations           | 29         |
# |    time_elapsed         | 75         |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.00928365 |
# |    clip_fraction        | 0.098      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.02      |
# |    explained_variance   | -0.716     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0443     |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.00837   |
# |    std                  | 0.849      |
# |    value_loss           | 0.338      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 870         |
# |    ep_rew_mean          | -98.9       |
# | time/                   |             |
# |    fps                  | 788         |
# |    iterations           | 30          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.012241278 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.97       |
# |    explained_variance   | 0.163       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.038       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0119     |
# |    std                  | 0.832       |
# |    value_loss           | 0.198       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 879         |
# |    ep_rew_mean          | -97.9       |
# | time/                   |             |
# |    fps                  | 787         |
# |    iterations           | 31          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.010971404 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.89       |
# |    explained_variance   | 0.059       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0375      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 0.815       |
# |    value_loss           | 0.136       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 862         |
# |    ep_rew_mean          | -98.1       |
# | time/                   |             |
# |    fps                  | 788         |
# |    iterations           | 32          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.005258564 |
# |    clip_fraction        | 0.0417      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.85       |
# |    explained_variance   | 0.0729      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.31        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00496    |
# |    std                  | 0.814       |
# |    value_loss           | 19.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 872          |
# |    ep_rew_mean          | -97.3        |
# | time/                   |              |
# |    fps                  | 788          |
# |    iterations           | 33           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0038371757 |
# |    clip_fraction        | 0.00791      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.84        |
# |    explained_variance   | 0.643        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.6          |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.0033      |
# |    std                  | 0.814        |
# |    value_loss           | 25.6         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 881        |
# |    ep_rew_mean          | -96.8      |
# | time/                   |            |
# |    fps                  | 789        |
# |    iterations           | 34         |
# |    time_elapsed         | 88         |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.00827604 |
# |    clip_fraction        | 0.105      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.8       |
# |    explained_variance   | -0.409     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.113      |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.00977   |
# |    std                  | 0.798      |
# |    value_loss           | 0.4        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 890         |
# |    ep_rew_mean          | -96.2       |
# | time/                   |             |
# |    fps                  | 790         |
# |    iterations           | 35          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.008106887 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.75       |
# |    explained_variance   | 0.378       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0781      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0083     |
# |    std                  | 0.791       |
# |    value_loss           | 0.154       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | -95         |
# | time/                   |             |
# |    fps                  | 790         |
# |    iterations           | 36          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.010201668 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.69       |
# |    explained_variance   | 0.598       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0377      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 0.778       |
# |    value_loss           | 0.109       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 907         |
# |    ep_rew_mean          | -94.3       |
# | time/                   |             |
# |    fps                  | 791         |
# |    iterations           | 37          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.007915895 |
# |    clip_fraction        | 0.0664      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.66       |
# |    explained_variance   | 0.721       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.49        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00583    |
# |    std                  | 0.775       |
# |    value_loss           | 3.79        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 916         |
# |    ep_rew_mean          | -93.6       |
# | time/                   |             |
# |    fps                  | 792         |
# |    iterations           | 38          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.009898665 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.63       |
# |    explained_variance   | 0.774       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0752      |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0135     |
# |    std                  | 0.769       |
# |    value_loss           | 0.158       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 892         |
# |    ep_rew_mean          | -94.9       |
# | time/                   |             |
# |    fps                  | 792         |
# |    iterations           | 39          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.015350688 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.6        |
# |    explained_variance   | 0.737       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0367      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0157     |
# |    std                  | 0.763       |
# |    value_loss           | 0.206       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 895          |
# |    ep_rew_mean          | -94.4        |
# | time/                   |              |
# |    fps                  | 793          |
# |    iterations           | 40           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0030559879 |
# |    clip_fraction        | 0.00361      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.58        |
# |    explained_variance   | 0.771        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.1         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00335     |
# |    std                  | 0.762        |
# |    value_loss           | 32.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 897          |
# |    ep_rew_mean          | -93.9        |
# | time/                   |              |
# |    fps                  | 793          |
# |    iterations           | 41           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0070566554 |
# |    clip_fraction        | 0.0414       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.58        |
# |    explained_variance   | 0.936        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.28         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00773     |
# |    std                  | 0.764        |
# |    value_loss           | 3.4          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 903          |
# |    ep_rew_mean          | -94.1        |
# | time/                   |              |
# |    fps                  | 791          |
# |    iterations           | 42           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0070844786 |
# |    clip_fraction        | 0.0479       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.59        |
# |    explained_variance   | 0.915        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.54         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00733     |
# |    std                  | 0.764        |
# |    value_loss           | 5.73         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 917         |
# |    ep_rew_mean          | -92.7       |
# | time/                   |             |
# |    fps                  | 790         |
# |    iterations           | 43          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.008685842 |
# |    clip_fraction        | 0.0759      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.59       |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.29        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00776    |
# |    std                  | 0.763       |
# |    value_loss           | 3.61        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 916         |
# |    ep_rew_mean          | -92.2       |
# | time/                   |             |
# |    fps                  | 790         |
# |    iterations           | 44          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.009239139 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.54       |
# |    explained_variance   | 0.449       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0638      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00927    |
# |    std                  | 0.748       |
# |    value_loss           | 0.216       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 923          |
# |    ep_rew_mean          | -91.5        |
# | time/                   |              |
# |    fps                  | 789          |
# |    iterations           | 45           |
# |    time_elapsed         | 116          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0076583414 |
# |    clip_fraction        | 0.0658       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.5         |
# |    explained_variance   | 0.919        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.54         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00801     |
# |    std                  | 0.747        |
# |    value_loss           | 3.21         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 930         |
# |    ep_rew_mean          | -90.6       |
# | time/                   |             |
# |    fps                  | 789         |
# |    iterations           | 46          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.012160342 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.48       |
# |    explained_variance   | 0.683       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0917      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0142     |
# |    std                  | 0.741       |
# |    value_loss           | 0.28        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 945          |
# |    ep_rew_mean          | -88.7        |
# | time/                   |              |
# |    fps                  | 787          |
# |    iterations           | 47           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0129286125 |
# |    clip_fraction        | 0.137        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.42        |
# |    explained_variance   | 0.699        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.134        |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.014       |
# |    std                  | 0.726        |
# |    value_loss           | 0.321        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | -87.6       |
# | time/                   |             |
# |    fps                  | 786         |
# |    iterations           | 48          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.008394909 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.36       |
# |    explained_variance   | 0.725       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0867      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00957    |
# |    std                  | 0.718       |
# |    value_loss           | 0.308       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | -86.3       |
# | time/                   |             |
# |    fps                  | 785         |
# |    iterations           | 49          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.013862755 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.31       |
# |    explained_variance   | 0.766       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.165       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0166     |
# |    std                  | 0.707       |
# |    value_loss           | 0.289       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 975         |
# |    ep_rew_mean          | -85.2       |
# | time/                   |             |
# |    fps                  | 784         |
# |    iterations           | 50          |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.011848874 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.831       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0894      |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0158     |
# |    std                  | 0.699       |
# |    value_loss           | 0.244       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 991         |
# |    ep_rew_mean          | -82.3       |
# | time/                   |             |
# |    fps                  | 783         |
# |    iterations           | 51          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.014589396 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.21       |
# |    explained_variance   | 0.818       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0947      |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0143     |
# |    std                  | 0.691       |
# |    value_loss           | 0.338       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+03    |
# |    ep_rew_mean          | -80.8       |
# | time/                   |             |
# |    fps                  | 780         |
# |    iterations           | 52          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.011470309 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0.796       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.125       |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.01       |
# |    std                  | 0.689       |
# |    value_loss           | 0.446       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# ...
# |    critic_loss     | 3.23     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 46316    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 454      |
# |    ep_rew_mean     | -108     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 72       |
# |    time_elapsed    | 729      |
# |    total_timesteps | 52817    |
# | train/             |          |
# |    actor_loss      | 16.1     |
# |    critic_loss     | 2.1      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 52716    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 472      |
# |    ep_rew_mean     | -108     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 72       |
# |    time_elapsed    | 757      |
# |    total_timesteps | 54809    |
# | train/             |          |
# |    actor_loss      | 14.6     |
# |    critic_loss     | 2.34     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 54708    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 478      |
# |    ep_rew_mean     | -107     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 72       |
# |    time_elapsed    | 770      |
# |    total_timesteps | 55711    |
# | train/             |          |
# |    actor_loss      | 15.5     |
# |    critic_loss     | 3.09     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 55610    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 516      |
# |    ep_rew_mean     | -105     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 72       |
# |    time_elapsed    | 825      |
# |    total_timesteps | 59868    |
# | train/             |          |
# |    actor_loss      | 13.7     |
# |    critic_loss     | 3.78     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 59767    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 569      |
# |    ep_rew_mean     | -102     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 72       |
# |    time_elapsed    | 902      |
# |    total_timesteps | 65501    |
# | train/             |          |
# |    actor_loss      | 12.3     |
# |    critic_loss     | 2.74     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 65400    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 598      |
# |    ep_rew_mean     | -100     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 72       |
# |    time_elapsed    | 950      |
# |    total_timesteps | 68827    |
# | train/             |          |
# |    actor_loss      | 11.8     |
# |    critic_loss     | 2.61     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 68726    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 629      |
# |    ep_rew_mean     | -96.1    |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 72       |
# |    time_elapsed    | 1023     |
# |    total_timesteps | 73944    |
# | train/             |          |
# |    actor_loss      | 11.1     |
# |    critic_loss     | 2.44     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 73843    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 642      |
# |    ep_rew_mean     | -94.3    |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 72       |
# |    time_elapsed    | 1048     |
# |    total_timesteps | 75662    |
# | train/             |          |
# |    actor_loss      | 9.52     |
# |    critic_loss     | 3.04     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 75561    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 642      |
# |    ep_rew_mean     | -92.9    |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 72       |
# |    time_elapsed    | 1059     |
# |    total_timesteps | 76394    |
# | train/             |          |
# |    actor_loss      | 9.89     |
# |    critic_loss     | 1.66     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 76293    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 656      |
# |    ep_rew_mean     | -91.1    |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 72       |
# |    time_elapsed    | 1086     |
# |    total_timesteps | 78313    |
# | train/             |          |
# |    actor_loss      | 10.2     |
# |    critic_loss     | 3.72     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 78212    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 666      |
# |    ep_rew_mean     | -91      |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 72       |
# |    time_elapsed    | 1111     |
# |    total_timesteps | 80024    |
# | train/             |          |
# |    actor_loss      | 11.9     |
# |    critic_loss     | 3.28     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79923    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 672      |
# |    ep_rew_mean     | -92.2    |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 71       |
# |    time_elapsed    | 1127     |
# |    total_timesteps | 81119    |
# | train/             |          |
# |    actor_loss      | 11.4     |
# |    critic_loss     | 4.21     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 81018    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 698      |
# |    ep_rew_mean     | -88.8    |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 71       |
# |    time_elapsed    | 1175     |
# |    total_timesteps | 84481    |
# | train/             |          |
# |    actor_loss      | 11.8     |
# |    critic_loss     | 2.8      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 84380    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 728      |
# |    ep_rew_mean     | -83.8    |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 71       |
# |    time_elapsed    | 1224     |
# |    total_timesteps | 87875    |
# | train/             |          |
# |    actor_loss      | 12.5     |
# |    critic_loss     | 2.64     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 87774    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 719      |
# |    ep_rew_mean     | -80.5    |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 71       |
# |    time_elapsed    | 1249     |
# |    total_timesteps | 89647    |
# | train/             |          |
# |    actor_loss      | 9.66     |
# |    critic_loss     | 4.77     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 89546    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 706      |
# |    ep_rew_mean     | -75.7    |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 71       |
# |    time_elapsed    | 1274     |
# |    total_timesteps | 91309    |
# | train/             |          |
# |    actor_loss      | 9.55     |
# |    critic_loss     | 4.02     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 91208    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 717      |
# |    ep_rew_mean     | -71.8    |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 71       |
# |    time_elapsed    | 1305     |
# |    total_timesteps | 93414    |
# | train/             |          |
# |    actor_loss      | 8.48     |
# |    critic_loss     | 4.06     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 93313    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 761      |
# |    ep_rew_mean     | -70.8    |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 71       |
# |    time_elapsed    | 1377     |
# |    total_timesteps | 98752    |
# | train/             |          |
# |    actor_loss      | 7.98     |
# |    critic_loss     | 4.76     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98651    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 802      |
# |    ep_rew_mean     | -70.7    |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 71       |
# |    time_elapsed    | 1444     |
# |    total_timesteps | 103137   |
# | train/             |          |
# |    actor_loss      | 6.36     |
# |    critic_loss     | 6.21     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 103036   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 822      |
# |    ep_rew_mean     | -71.8    |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 70       |
# |    time_elapsed    | 1497     |
# |    total_timesteps | 105623   |
# | train/             |          |
# |    actor_loss      | 6.45     |
# |    critic_loss     | 6.56     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 105522   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 781      |
# |    ep_rew_mean     | -73.1    |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 69       |
# |    time_elapsed    | 1533     |
# |    total_timesteps | 106921   |
# | train/             |          |
# |    actor_loss      | 5.64     |
# |    critic_loss     | 7.72     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 106820   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 757      |
# |    ep_rew_mean     | -74      |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 68       |
# |    time_elapsed    | 1608     |
# |    total_timesteps | 109604   |
# | train/             |          |
# |    actor_loss      | 1.91     |
# |    critic_loss     | 5.99     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 109503   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 755      |
# |    ep_rew_mean     | -73.6    |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 66       |
# |    time_elapsed    | 1678     |
# |    total_timesteps | 112039   |
# | train/             |          |
# |    actor_loss      | 2.79     |
# |    critic_loss     | 3.91     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 111938   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 750      |
# |    ep_rew_mean     | -70.1    |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 64       |
# |    time_elapsed    | 1792     |
# |    total_timesteps | 116333   |
# | train/             |          |
# |    actor_loss      | 0.996    |
# |    critic_loss     | 3.4      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 116232   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 750      |
# |    ep_rew_mean     | -64.6    |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 62       |
# |    time_elapsed    | 1928     |
# |    total_timesteps | 121422   |
# | train/             |          |
# |    actor_loss      | 4.93     |
# |    critic_loss     | 5.97     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 121321   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 738      |
# |    ep_rew_mean     | -52.3    |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 62       |
# |    time_elapsed    | 2015     |
# |    total_timesteps | 126651   |
# | train/             |          |
# |    actor_loss      | 3.34     |
# |    critic_loss     | 4.02     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 126550   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 764      |
# |    ep_rew_mean     | -56.2    |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 63       |
# |    time_elapsed    | 2079     |
# |    total_timesteps | 131238   |
# | train/             |          |
# |    actor_loss      | 2.65     |
# |    critic_loss     | 3.29     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 131137   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 812      |
# |    ep_rew_mean     | -42.7    |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 63       |
# |    time_elapsed    | 2162     |
# |    total_timesteps | 136868   |
# | train/             |          |
# |    actor_loss      | 1.87     |
# |    critic_loss     | 2.37     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 136767   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 794      |
# |    ep_rew_mean     | -38.8    |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 63       |
# |    time_elapsed    | 2197     |
# |    total_timesteps | 139275   |
# | train/             |          |
# |    actor_loss      | 0.365    |
# |    critic_loss     | 2.71     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 139174   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 781      |
# |    ep_rew_mean     | -26.1    |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 63       |
# |    time_elapsed    | 2260     |
# |    total_timesteps | 143568   |
# | train/             |          |
# |    actor_loss      | 0.201    |
# |    critic_loss     | 4.53     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 143467   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 788      |
# |    ep_rew_mean     | -11.7    |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 63       |
# |    time_elapsed    | 2320     |
# |    total_timesteps | 147656   |
# | train/             |          |
# |    actor_loss      | 2.15     |
# |    critic_loss     | 1.53     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 147555   |
# ---------------------------------
# Resultado TD3: 275.13 +/- 0.86

# %% [markdown]
# ## 2.2. Análise dos Resultados Preliminares
#
# Após o treino dos algoritmos candidatos, recolhemos as métricas de desempenho. O gráfico abaixo compara a recompensa média obtida por cada agente no ambiente `BipedalWalker-v3` após 150.000 passos de treino.
#
# *Critério de Sucesso:* O ambiente é considerado resolvido com 300 pontos. Procuramos o algoritmo que mais se aproxima deste valor ou que demonstra a curva de aprendizagem mais ascendente.

# %%
# Lista dos algoritmos treinados (tem de bater certo com o que definiste em cima)
algos_names = ["PPO", "SAC", "TD3", "A2C"]

results_data = []

print("--- A carregar modelos para gerar o gráfico comparativo ---")

for name in algos_names:
    model_path = f"{MODEL_DIR}/{name}_base.zip"
    
    if os.path.exists(model_path):
        try:
            # Identificar a classe (hack simples para saber qual carregar)
            if name == "PPO": AlgoClass = PPO
            elif name == "SAC": AlgoClass = SAC
            elif name == "A2C": AlgoClass = A2C
            elif name == "TD3": AlgoClass = TD3
            
            # Carregar e Avaliar
            model = AlgoClass.load(model_path, device="cpu")
            env = gym.make("BipedalWalker-v3")
            mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)
            
            results_data.append({
                "Algoritmo": name,
                "Média Reward": mean_reward,
                "Desvio Padrão": std_reward
            })
            print(f"✅ {name}: {mean_reward:.1f}")
            env.close()
            
        except Exception as e:
            print(f"⚠️ Erro ao carregar {name}: {e}")
    else:
        print(f"⏩ Modelo {name} não encontrado (talvez não tenha acabado de treinar).")

# Gerar Gráfico
if results_data:
    df_results = pd.DataFrame(results_data)
    
    plt.figure(figsize=(10, 6))
    sns.barplot(data=df_results, x="Algoritmo", y="Média Reward", palette="viridis", yerr=df_results["Desvio Padrão"])
    plt.axhline(300, color="green", linestyle="--", label="Objetivo (300 pts)")
    plt.title("Comparação de Algoritmos (150k Steps)")
    plt.ylabel("Recompensa Média (10 Episódios)")
    plt.legend()
    plt.show()
    
    # Mostrar Tabela
    display(df_results.sort_values(by="Média Reward", ascending=False))
else:
    print("Nenhum resultado para mostrar.")

# %% [markdown]
# ## 2.3. Otimização de Hiperparâmetros (Tuning)
#
# Com base na comparação acima, selecionámos o algoritmo com melhor desempenho (ou potencial) para a fase final.
#
# Para cumprir o requisito de **Hyperparameter Tuning**, vamos realizar uma experiência focada na **Taxa de Aprendizagem (Learning Rate)**, que é o parâmetro mais sensível em Reinforcement Learning.
#
# **Vencedor Selecionado:** *[ESCREVE AQUI O NOME, EX: SAC]*

# %%
# --- CONFIGURAÇÃO MANUAL ---
WINNER_NAME = "SAC"  # <--- ALTERA ISTO PARA O TEU VENCEDOR (ex: "PPO", "TQC")
# ---------------------------

# Mapear string para classe
algos_map = {"PPO": PPO, "SAC": SAC, "TD3": TD3, "A2C": A2C}

WinnerClass = algos_map[WINNER_NAME]

# Definir as variantes de Learning Rate a testar
learning_rates = {
    "LR_Baixo (1e-4)": 0.0001,
    "LR_Medio (3e-4)": 0.0003, # Valor comum por defeito
    "LR_Alto (1e-3)": 0.001
}

tuning_results = []
print(f"--- INICIANDO TUNING DO {WINNER_NAME} ---")

for label, lr in learning_rates.items():
    print(f"Testando {label}...")
    
    # Usar nomes de pastas diferentes para não misturar
    log_name = f"{WINNER_NAME}_{label}"
    
    env = gym.make("BipedalWalker-v3")
    
    try:
        # Treinar com o novo Learning Rate
        # Reduzimos um pouco os steps (100k) para ser mais rápido, já que é só afinação
        model = WinnerClass("MlpPolicy", env, learning_rate=lr, verbose=0, tensorboard_log=LOG_DIR)
        model.learn(total_timesteps=100_000, tb_log_name=log_name)
        
        # Guardar para referência
        model.save(f"{MODEL_DIR}/{log_name}")
        
        # Avaliar
        mean, std = evaluate_policy(model, env, n_eval_episodes=5)
        tuning_results.append({"Configuração": label, "LR": lr, "Reward": mean, "Std": std})
        print(f"   -> Resultado: {mean:.2f}")
        
    except Exception as e:
        print(f"   Erro: {e}")
    finally:
        env.close()

# Tabela Final de Tuning
df_tuning = pd.DataFrame(tuning_results)
display(df_tuning.sort_values(by="Reward", ascending=False))

# %% [markdown]
# ## Conclusão da Fase 2
#
# Concluímos a seleção e otimização do agente:
#
# 1.  **Algoritmo Escolhido:** O **[NOME]** demonstrou ser superior aos restantes.
# 2.  **Configuração Ótima:** A learning rate de **[VALOR]** permitiu uma convergência mais estável/rápida.
#
# Este modelo otimizado servirá agora de "Baseline" para a próxima etapa: testar a robustez do agente no ambiente modificado (**InjuredBipedalWalker**).
